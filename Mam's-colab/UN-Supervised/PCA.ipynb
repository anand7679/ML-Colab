# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
data = load_iris()
X = data.data
y = data.target

# %%
plt.scatter(X[:,0],X[:,1],c=y)
plt.title("unscaled data")
# Out:
# Text(0.5, 1.0, 'unscaled data')

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(X)

# %%
plt.scatter(x_scaled[:,0],x_scaled[:,1],c=y)
plt.title("scaled data")
# Out:
# Text(0.5, 1.0, 'scaled data')

# %%
pca = PCA(n_components=2)
pca_data = pca.fit_transform(x_scaled)
df = pd.DataFrame(pca_data,columns=["PC1","PC2"])
df["target"] = y
df
# Out:
#           PC1       PC2  target
# 0   -2.264703  0.480027       0
# 1   -2.080961 -0.674134       0
# 2   -2.364229 -0.341908       0
# 3   -2.299384 -0.597395       0
# 4   -2.389842  0.646835       0
# ..        ...       ...     ...
# 145  1.870503  0.386966       2
# 146  1.564580 -0.896687       2
# 147  1.521170  0.269069       2
# 148  1.372788  1.011254       2
# 149  0.960656 -0.024332       2
#
# [150 rows x 3 columns]

# %%
plt.scatter(df["PC1"],df["PC2"],c=df["target"])
plt.title("pca data")
# Out:
# Text(0.5, 1.0, 'pca data')

# %%
pca = PCA(n_components=0.95)  #95% of the data should be present by removing some noise
pca_data = pca.fit_transform(x_scaled)
df = pd.DataFrame(pca_data,columns=["PC1","PC2"])
df["target"] = y
df
# Out:
#           PC1       PC2  target
# 0   -2.264703  0.480027       0
# 1   -2.080961 -0.674134       0
# 2   -2.364229 -0.341908       0
# 3   -2.299384 -0.597395       0
# 4   -2.389842  0.646835       0
# ..        ...       ...     ...
# 145  1.870503  0.386966       2
# 146  1.564580 -0.896687       2
# 147  1.521170  0.269069       2
# 148  1.372788  1.011254       2
# 149  0.960656 -0.024332       2
#
# [150 rows x 3 columns]

# %%
plt.scatter(df["PC1"],df["PC2"],c=df["target"])
plt.title("pca data 95%")
# Out:
# Text(0.5, 1.0, 'pca data 95%')
